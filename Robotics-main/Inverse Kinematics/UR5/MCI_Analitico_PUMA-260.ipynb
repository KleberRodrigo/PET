# %% [markdown]
# <h1 align='center'>
#     Manipulador UR5
# <h1>

# %% [markdown]
# <div align="center">
#     <img src="UR5.png">
# </div>

# %%
from FKM import *

# %% [markdown]
# ### Definição da Tabela de Denavit Hartenberg:

# %%
UR5 = Robot((
    [theta1, 89.2, 0, rad(90)],
    [theta2, 0, 425, 0],
    [theta3, 0, 392, 0],
    [theta4, 109.3, 0, rad(90)],
    [theta5, 94.75, 0, -rad(90)],
    [theta6, 82.5, 0, 0]
))

# %% [markdown]
# ### Modelo Cinemático Direto:

# %%
H06 = UR5.HTM(0, 6)

H06
# Out:
# ⎡-c₁⋅s₂₃₄⋅s₆ + c₆⋅(c₁⋅c₂₃₄⋅c₅ + s₁⋅s₅)  -c₁⋅c₆⋅s₂₃₄ - s₆⋅(c₁⋅c₂₃₄⋅c₅ + s₁⋅s₅)
# ⎢
# ⎢c₆⋅(-c₁⋅s₅ + c₂₃₄⋅c₅⋅s₁) - s₁⋅s₂₃₄⋅s₆  -c₆⋅s₁⋅s₂₃₄ - s₆⋅(-c₁⋅s₅ + c₂₃₄⋅c₅⋅s₁)
# ⎢
# ⎢        c₂₃₄⋅s₆ + c₅⋅c₆⋅s₂₃₄                    c₂₃₄⋅c₆ - c₅⋅s₂₃₄⋅s₆
# ⎢
# ⎣                  0                                      0
#
#   -c₁⋅c₂₃₄⋅s₅ + c₅⋅s₁  -82.5⋅c₁⋅c₂₃₄⋅s₅ + 94.75⋅c₁⋅s₂₃₄ + c₁⋅(425⋅c₂ + 392⋅c₂₃
#
#   -c₁⋅c₅ - c₂₃₄⋅s₁⋅s₅  -82.5⋅c₁⋅c₅ - 109.3⋅c₁ - 82.5⋅c₂₃₄⋅s₁⋅s₅ + 94.75⋅s₁⋅s₂₃
#
#        -s₂₃₄⋅s₅                    -94.75⋅c₂₃₄ + 425.0⋅s₂ + 392.0⋅s₂₃ - 82.5⋅s
#
#            0                                                  1
#
# ) + 82.5⋅c₅⋅s₁ + 109.3⋅s₁⎤
#                          ⎥
# ₄ + s₁⋅(425⋅c₂ + 392⋅c₂₃)⎥
#                          ⎥
# ₂₃₄⋅s₅ + 89.2            ⎥
#                          ⎥
#                          ⎦

# %%
R = UR5.HTM(4, 6)[:3, :3]
O = UR5.HTM(4, 6)[:3, 3]

-R.T@O
# Out:
# ⎡      94.75⋅s₆       ⎤
# ⎢                     ⎥
# ⎢      94.75⋅c₆       ⎥
# ⎢                     ⎥
# ⎢         2          2⎥
# ⎣- 82.5⋅c₅  - 82.5⋅s₅ ⎦

# %%
UR5.HTM(3, 4)
